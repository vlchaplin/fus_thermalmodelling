# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import collections
from matplotlib import image

from math import *;

# %matplotlib inline

# %%
kappa = 0.5
Cv = 3100
tau = 0.01

K = Cv*kappa
L = sqrt(kappa*tau)

dv=1
qvdot_wattsPerVolume = 1000/dv
C = qvdot_wattsPerVolume*dv/(8*pi*K)

def T(r,t):
    tstar = np.sqrt(t/tau)
    R = r/np.sqrt(4*kappa*t)
    return (C/r)*(np.exp(-r/L)*(2 - erfc(tstar - R)) + np.exp(r/L)*erfc(tstar + R) )

# %%
r = np.logspace( log10(0.01*L), log10(2*L),100)
t = np.logspace( log10(0.01*tau), log10(2*tau),100)

# %%
r = np.linspace( (0.01*L), (L),100)
t = np.linspace( (0.01*tau), (tau),100)

# %%
Tm = np.zeros([len(r),len(t)])
ti=0
for tq in t:
    ri=0
    for rq in r:
        Tm[ri,ti] = T(rq,tq)
        ri+=1
    ti+=1

gr,gt= np.meshgrid( r,t,sparse=False, indexing='ij' )

# %%
map( lambda r: T(r, 0.1), r)

# %%
fig = plt.figure(figsize=(16,6), dpi=72)

plt.plot(t, list(map( lambda t: T(0.1*L, t), t)))
plt.plot(t, list(map( lambda t: T(L, t), t)))
plt.plot(t, list(map( lambda t: T(3*L, t), t)))

# %%
fig = plt.figure(figsize=(16,6), dpi=72)

plt.plot(r, list(map( lambda r: T(r, 0.1), t)))
plt.plot(r, list(map( lambda r: T(r, 8), t)))
plt.plot(r, list(map( lambda r: T(r, 10), t)))

# %%
fig = plt.figure(figsize=(16,6), dpi=72)

ax = fig.add_subplot(111, projection='3d')

ax.plot_surface( gr, gt, Tm)
ax.set_xlabel('r')
ax.set_ylabel('t')

# %%
Tm.shape
# Out:
# (3, 2)

# %%
coords[0].shape
# Out:
# (2, 3)

# %%
r
# Out:
# array([ 10.00375002,  10.11831123,  10.23476058,  10.35313588,
#         10.4734758 ,  10.59581991,  10.72020874,  10.84668371,
#         10.97528728,  11.10606285,  11.23905489,  11.3743089 ,
#         11.51187147,  11.6517903 ,  11.79411423,  11.93889326,
#         12.08617862,  12.23602276,  12.38847938,  12.54360352,
#         12.70145154,  12.86208116,  13.02555155,  13.1919233 ,
#         13.36125851,  13.53362082,  13.70907541,  13.88768912,
#         14.06953045,  14.25466958,  14.44317849,  14.63513095,
#         14.83060258,  15.02967095,  15.23241555,  15.43891793,
#         15.6492617 ,  15.86353263,  16.08181868,  16.30421007,
#         16.53079936,  16.76168151,  16.99695395,  17.23671664,
#         17.48107216,  17.73012578,  17.98398554,  18.24276233,
#         18.50656999,  18.77552535,  19.04974839,  19.32936227,
#         19.61449346,  19.90527182,  20.20183073,  20.50430716,
#         20.81284181,  21.1275792 ,  21.44866779,  21.77626013,
#         22.11051293,  22.45158724,  22.79964855,  23.15486694,
#         23.51741723,  23.88747911,  24.2652373 ,  24.6508817 ,
#         25.04460758,  25.44661569,  25.85711251,  26.27631037,
#         26.70442765,  27.14168899,  27.58832547,  28.04457484,
#         28.51068168,  28.98689771,  29.47348192,  29.97070087,
#         30.47882892,  30.99814849,  31.52895029,  32.07153363,
#         32.6262067 ,  33.19328684,  33.77310084,  34.36598528,
#         34.97228684,  35.59236265,  36.2265806 ,  36.87531976,
#         37.53897069,  38.21793589,  38.91263016,  39.62348105,
#         40.35092926,  41.09542912,  41.85744904,  42.63747199])
