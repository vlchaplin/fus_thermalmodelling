# %%
import numpy as np;
import matplotlib.pyplot as plt
from math import *;

import sys;

# add path to the C++ extension library (PBHEswig)
sys.path.append('C:\\Users\\vchaplin\\Documents\\HiFU\code\\BioHeatCpp\\PBHEswig\\x64');

import PBHEswig;

# %matplotlib inline

# %%
dt = 0.1
voxSide = 1e-3
res = np.array([dt,voxSide,voxSide,voxSide]);
dx = dy = dz = voxSide
Nx = 50
Ny = 50
Nz = 50
Nt = 20


# ----- allocate numpy data arrays --- #
T = np.zeros([Nt,Nx,Ny,Nz])
Tdot = np.zeros([Nx,Ny,Nz])
kdiff = np.zeros([Nx,Ny,Nz])
rhoCp = np.zeros([Nx,Ny,Nz])

# ---- Create C++ mesh objects ---
Tmesh = PBHEswig.mesh4d()
Tdotmesh = PBHEswig.mesh34d();
kmesh = PBHEswig.mesh3d();
rhoCpmesh = PBHEswig.mesh3d();

# ----- tie data arrays to mesh objects (to pass to C++) ---
# the data in each mesh can now be accessed/manipulated from python via the arrays, 'T', 'Tdot', etc.
PBHEswig.ShareMemoryMesh4(T, res, Tmesh)
PBHEswig.ShareMemoryMesh34(Tdot, res, Tdotmesh)
PBHEswig.ShareMemoryMesh3(kdiff, res[1:4], kmesh)
PBHEswig.ShareMemoryMesh3(rhoCp, res[1:4], rhoCpmesh)

# %%
del [T,Tdot,kdiff,rhoCp,Tdotmesh,kmesh,rhoCpmesh]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-a3e047855e5e> in <module>()
# ----> 1 del [T,Tdot,kdiff,rhoCp,Tdotmesh,kmesh,rhoCpmesh]
#
# NameError: name 'T' is not defined

# %%
#initial conditions
T[:] = 37.0
Tdot[:] = 1;
kdiff[:] = 0.5;
rhoCp[:] = 3700*1000;

perfRate = 0.01;

sx=Nx/10
for xi in range(0,Nx):
    for yi in range(0,Ny):
        for zi in range(0,Nz):
            Tdot[xi,yi,zi] = 1.0*np.exp( -(xi+0.5 - Nx/2)**2/(2*(sx)**2) )*np.exp( -(yi+0.5 - Ny/2)**2/(2*(sx)**2) )*np.exp( -(zi+0.5 - Nz/2)**2/(2*(sx)**2) ) 
            

# total number of sonications
Nson = 1


# feed-back control time (must be >= dt for obvious reasons, and <= Nt*dt b.c. that's convenient programming for now)
tempCheckInterval_sec = 1.0

#first make sure times are all digitized based on finite simulation rate
if Nt*dt > tempCheckInterval_sec:
    nnt = round(tempCheckInterval_sec/dt);
    tempCheckInterval_sec = nnt*dt;
elif tempCheckInterval_sec > Nt*dt:
    nnt = Nt
    tempCheckInterval_sec = nnt*dt
else:
    nnt=Nt
    
# free parameter: Active dwell time
activeDwellTime_sec = 25.0

numAcqPoints = round(activeDwellTime_sec/tempCheckInterval_sec)
activeDwellTime_sec = numAcqPoints*tempCheckInterval_sec

#retain CEM map for each acquisition in this sonication
CEMthis = np.zeros([numAcqPoints,Nx,Ny,Nz])

aqcidx = 0;
time = 0
step = tempCheckInterval_sec

tacqstops = step*np.array(range(1,numAcqPoints+1))

while aqcidx<numAcqPoints :
    print("Doing acqidx ",aqcidx)
    PBHEswig.pbheSolve(0,dt,dx,dy,dz, Tmesh, Tdotmesh, kmesh, rhoCpmesh, 37.0, perfRate,0,nnt-1 )
    Rbase = 4*np.ones([nnt,Nx,Ny,Nz]);
    Rbase[np.where(T[0:,nnt] > 43.0, True, False)] = 2
    
    #time integrate to get the thermal dose
    CEMthis[aqcidx] = dt*np.sum( Rbase**(T[0:nnt]-43), 0  )
    aqcidx+=1
    time+=step
    T[0] = T[nnt-1]
# Out:
# Doing acqidx  0
# Doing acqidx
#  1
# Doing acqidx
#  2
# Doing acqidx
#  3
# Doing acqidx
#  4
# Doing acqidx
#  5
# Doing acqidx
#  6
# Doing acqidx
#  7
# Doing acqidx
#  8
# Doing acqidx
#  9
# Doing acqidx
#  10
# Doing acqidx
#  11
# Doing acqidx
#  12
# Doing acqidx
#  13
# Doing acqidx
#  14
# Doing acqidx
#  15
# Doing acqidx
#  16
# Doing acqidx
#  17
# Doing acqidx
#  18
# Doing acqidx
#  19
# Doing acqidx
#  20
# Doing acqidx
#  21
# Doing acqidx
#  22
# Doing acqidx
#  23
# Doing acqidx
#  24

# %%
CEMthis.shape
# Out:
# (5, 50, 50, 50)

# %%
T[4,25,25,25]
# Out:
# 53.421133468952306

# %%
fig = plt.figure(figsize=(7,4), dpi=72)
ax = fig.gca()

plt.plot(tacqstops,CEMthis[:,floor(Nx/2),floor(Ny/2),floor(Nz/2)])

# %%
fig = plt.figure(figsize=(7,4), dpi=72)
ax = fig.gca()

plt.plot(CEMthis[0:14,floor(Nx/2),floor(Ny/2),floor(Nz/2)])

# %%
ti=12;
plt.imshow( CEMthis[ti,:,:,floor(Nz/2)] )
plt.colorbar()

# %%
plt.imshow( CEMthis[ti,:,floor(Ny/2),:] )
plt.colorbar()

# %%
import sys
sys.path.append('C:\\Users\\vchaplin\\Documents\\HiFU\code\\myPy')  
from countlines import countlines
import re
import geom
import sonalleve
import math
import numpy as np

# %%
import numpy as np;
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import collections
from matplotlib import image

from math import *;

# %matplotlib inline

# %%
fig = plt.figure(figsize=(12,12), dpi=72)
ax = fig.gca(projection='3d')

p=ax.plot3D(v[:,0], v[:,1], v[:,2], '.')

#collections.CircleCollection

#activeCol = collections.PolyCollection( vvXYact, closed='false', facecolors='w', edgecolor='r' );
#activeCol.set_linewidths(1.0)
#activeCol.set_facecolors([0, 0.8, 1])
#activeCol.set_edgecolors([0,0,0]);

#col = collections.PolyCollection( vvXY, closed='false', facecolors='w', edgecolor='r' );
#col.set_linewidths(1.0)

#col.set_facecolors([1, 1, 1])
#col.set_edgecolors([0,0,0]);

ax.set_xlim3d( [-0.06,0.06]);
ax.set_ylim3d( [-0.06,0.06]);
ax.set_zlim3d( [0,0.15]);
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
#ax.set_ylim3d(0,100);
#ax.add_collection3d(col)
#ax.add_collection3d(activeCol)
ax.view_init(10,90)

# %%
pxyz=np.array([[-0.02,0,0.14], [-0.01,0,0.14], [0.01,0,0.14], [0.02,0,0.14]])
p0 = 1e07*np.ones(4)

uxyz = sonalleve.get_sonalleve_xdc_vecs()

# %%
w0 = 1.2e6*2*pi
c = 1540
k = w0/c
uamp = sonalleve.get_focused_element_vals(k, uxyz, pxyz,p0)

# %%
d=0.0025;
h=d*sin(pi/3);

triangle = np.array([[-d/2, -h/2, 0.0], [d/2, -h/2, 0.0], [0, h/2, 0] ])
#pxyz=geom.getRotZYZarray(0,0,0).dot(triangle)
pxyz=triangle;
pxyz[:,2]=0.14
p0 = 1e7*np.ones(len(pxyz));
uamp = sonalleve.get_focused_element_vals(k, uxyz, pxyz,p0)

# %%
xp = 1e-2*np.linspace(-6, 6., 400)
yp = 1e-2*np.linspace(-6, 6., 100)
zp = 0.01*np.linspace(0.0, 20.0, 400)

#xp=[0.0];
yp=[0.0];
zp=[0.135,0.14,0.16]

#uamp[:] = 0.2

P = sonalleve.calc_pressure_field(k, uxyz, uamp, xp, yp, zp)
I = np.abs(P)**2
I *= (1e7/np.max(I))

# %%
plt.plot(100*xp,I[:,0,0])
plt.plot(100*xp,I[:,0,1], 'g')
plt.plot(100*xp,I[:,0,2], 'r')

# %%
xp = 0.01*np.linspace(-6, 6., 400)
yp = 0.01*np.linspace(-6, 6., 100)
zp = 0.01*np.linspace(0.0, 18.0, 400)

yp=[0.0];
xp=[0.0];

P = sonalleve.calc_pressure_field(k, uxyz, uamp, xp, yp, zp)
I = np.abs(P)**2
plt.plot(100*zp,I[0,0,:])

# %%
xp = 1e-2*np.linspace(-8,8., 200)
yp = [0.0];
zp = 0.01*np.linspace(0.0, 20.0, 200)

P = sonalleve.calc_pressure_field(k, geom.translate3vecs( uxyz, np.array([0.00,0.0,0.0]) ), uamp, xp, yp, zp)
I = 0.5*np.abs(P)**2 / (2.0*3700*c)

fig = plt.figure(figsize=(7,7), dpi=72)
plt.imshow(np.transpose(I[:,0,:]), cmap=image.cm.jet, origin='lower', extent=list(map(lambda x: x*100,[xp[0], xp[-1], zp[0], zp[-1]])) )

# %%
uamp = np.array([-0.045691+1j*(-0.046512) , -0.067743+1j*(-0.069517) , -0.072339+1j*(-0.083957) , -0.084009+1j*(-0.084099) , -0.081376+1j*(-0.070278) , -0.067620+1j*(-0.059943) , -0.047908+1j*(-0.034054) , -0.011769+1j*(-0.006736) , 0.008306+1j*(0.026183) , 0.045707+1j*(0.048022) , 0.078811+1j*(0.079693) , 0.084366+1j*(0.101274) , 0.101773+1j*(0.101915) , 0.097591+1j*(0.094078) , 0.080331+1j*(0.071218) , 0.066793+1j*(0.063474) , -0.045694+1j*(-0.046511) , -0.067741+1j*(-0.069513) , -0.072338+1j*(-0.083957) , -0.084009+1j*(-0.084096) , -0.081373+1j*(-0.070268) , -0.067620+1j*(-0.059939) , -0.047903+1j*(-0.034056) , -0.011769+1j*(-0.006738) , 0.008306+1j*(0.026185) , 0.045711+1j*(0.048017) , 0.078809+1j*(0.079684) , 0.084365+1j*(0.101269) , 0.101782+1j*(0.101903) , 0.097593+1j*(0.094065) , 0.080330+1j*(0.071206) , 0.066796+1j*(0.063476) , -0.045691+1j*(-0.046512) , -0.067743+1j*(-0.069517) , -0.072339+1j*(-0.083957) , -0.084009+1j*(-0.084099) , -0.081376+1j*(-0.070278) , -0.067620+1j*(-0.059943) , -0.047908+1j*(-0.034054) , -0.011769+1j*(-0.006736) , 0.008306+1j*(0.026183) , 0.045707+1j*(0.048022) , 0.078811+1j*(0.079693) , 0.084366+1j*(0.101274) , 0.101773+1j*(0.101915) , 0.097591+1j*(0.094078) , 0.080331+1j*(0.071218) , 0.066793+1j*(0.063474) , -0.045694+1j*(-0.046511) , -0.067741+1j*(-0.069513) , -0.072338+1j*(-0
# %%
2*pi/k
# Out:
# 0.0012833333333333332

# %%
xp = 1e-2*np.linspace(-8,8., 150)
yp = [0.0];
zp = 0.01*np.linspace(12, 16.0, 150)



P = sonalleve.calc_pressure_field(k, uxyz, uamp, xp, yp, zp)

I = np.abs(P)**2

plt.figure(figsize=(7,7), dpi=72)
plt.imshow(np.transpose(I[:,0,:]), cmap=image.cm.hot, origin='lower', extent=[xp[0], xp[-1], zp[0], zp[-1]])

# %%
xp = 1e-2*np.linspace(-2,2., 250)
yp = xp;
zp = [0.14]



P = sonalleve.calc_pressure_field(k, uxyz, uamp, xp, yp, zp)
P[:] += sonalleve.calc_pressure_field(k, geom.translate3vecs( uxyz, np.array([0, 2*h+h/2,0.0]) ), uamp, xp, yp, zp)
P[:] += sonalleve.calc_pressure_field(k, geom.translate3vecs( uxyz, np.array([d*5.0/2,3/2*h,0.0]) ), uamp, xp, yp, zp)

I = np.abs(P)**2

plt.figure(figsize=(7,7), dpi=72)
plt.imshow(np.transpose(I[:,:,0]), cmap=image.cm.hot, origin='lower', extent=[xp[0], xp[-1], yp[0], yp[-1]])

# %%
r_foc = 0.14
Nx=3;
Ny=3;
Nz=100;

#xrp = np.linspace(-0.02, 0.02, Nx);
#yrp = np.linspace(-0.02, 0.02, Ny);
#zrp = np.linspace(r_foc - 0.03, r_foc + 0.03, Nz+1);
xrp=[0.0]; Nx=1
yrp=[0.0]; Ny=1;
zrp=np.linspace(0.1,0.18,Nz);

# %%
Ir = np.abs(Pr)

# %%
P = sonalleve.calc_pressure_field(kr, uxyz, uamp, xrp, yrp, zrp)
I = np.abs(P)**2

# %%
yrp
# Out:
# array([-0.02,  0.  ,  0.02])

# %%
plt.plot(zrp,I[0,0,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-f9adc41fe1ca> in <module>()
#       1
# ----> 2 plt.plot(zrp,I[0,0,:])
#
# NameError: name 'zrp' is not defined

# %%
uim = np.array([0.687760, 0.661529, -0.143151, -0.216244, -0.335534, -0.789709, -0.790763, -0.778450, -0.662801, -0.355874, -0.301013, -0.168906, -0.026276, 0.067189, 0.113906, 0.113340, 0.099272, 0.076085, 0.074752, 0.077604, 0.226372, 0.234585, 0.282620, 0.539677, 0.549920, 0.552858, 0.428154, 0.331379, -0.034194, -0.257638, -0.359101, -0.431835, 0.687730, 0.661539, -0.143158, -0.216260, -0.335541, -0.789706, -0.790761, -0.778488, -0.662845, -0.355953, -0.301015, -0.168909, -0.026230, 0.067134, 0.113924, 0.113122, 0.099219, 0.075868, 0.074645, 0.077715, 0.226362, 0.234526, 0.282610, 0.539577, 0.550107, 0.552607, 0.428186, 0.331220, -0.034196, -0.257594, -0.359123, -0.431859, 0.687760, 0.661529, -0.143151, -0.216244, -0.335534, -0.789709, -0.790763, -0.778450, -0.662801, -0.355874, -0.301013, -0.168906, -0.026276, 0.067189, 0.113906, 0.113340, 0.099272, 0.076085, 0.074752, 0.077604, 0.226372, 0.234585, 